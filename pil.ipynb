# %%
import PIL
PIL.__version__

# %%
from PIL import Image
im = Image.open("image/prayuth.png")
im.show()

# %%
import numpy as np
im_arr = np.array(im)

im_inverted = Image.fromarray(np.array([255 - i for i in im_arr]))
im_inverted
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
im_converted_back = Image.fromarray(im_arr)
im_converted_back

# %%
w, h = im.size
# Out:
# (1280, 720)

# %%
im_inverted.save("image/inverted_prayuth.png")

# %% [markdown]
# ## Convert to Gray scale

# %%
# RGB, L
im.convert("L").show()

# %% [markdown]
# ## Resize & Crop

# %%
im.resize((180, 300)).show()

# %%
coordinates = (300, 400, 700, 900)
im.crop(coordinates).show()

# %% [markdown]
# ## Rotate & flip

# %%
im.rotate(340, fillcolor=(100, 80, 255))
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
im.transpose(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %% [markdown]
# ## HW

# %% [markdown]
# 1. Resize ให้ด้านที่ยาวที่สุดมีขนาด x แล้วคืนค่าเป็นรูปที่ถูก resize ที่ maintain aspect ratio เดิม

# %%
def resize_maintain_ratio(im: Image, x: int) -> Image:
    
    return

# %% [markdown]
# 2. สร้าง function ที่เปลี่ยน (left, upper, right, lower) -> (x,y,w,h)

# %%
def convert_lurl2xywh(coordinates: tuple[int, int, int, int]) -> tuple:
    
    return
